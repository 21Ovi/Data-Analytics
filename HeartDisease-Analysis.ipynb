# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('heart-disease.csv')

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
data["age"].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data.plot.hist(figsize=(10,30),subplots=True);

# %%
over_50 = data[data['age'] > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# 4        2   0     2       1
# 5        1   0     1       1
# 6        1   0     2       1
# ..     ...  ..   ...     ...
# 297      1   2     1       0
# 298      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [208 rows x 14 columns]

# %%
over_50.plot(kind='scatter',x='age',y='chol',c='target')
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
fig, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind='scatter',x='age',y='chol',c='target',ax=ax);

# %%
fig, ax = plt.subplots(figsize=(10,6))

scatter = ax.scatter(x=over_50['age'],y=over_50['chol'],c=over_50['target'])

ax.set(title="Heart Diesase and cholestrol level",xlabel='Age',ylabel='Cholestrol')
ax.legend(*scatter.legend_elements(),title='target')

ax.axhline(over_50["chol"].mean(),linestyle='--');

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2,ncols=1,figsize=(10,10),sharex=True)

scatter = ax0.scatter(x=over_50['age'],y=over_50['chol'],c=over_50['target'])
ax0.set(title="Heart diease vs cholestrol levels",ylabel='Cholestrol')
ax0.legend(*scatter.legend_elements(),title='Target')
ax0.axhline(y=over_50['chol'].mean(),linestyle='--');

scatter = ax1.scatter(x=over_50['age'],y=over_50['thalach'],c=over_50['target'])
ax1.set(title="Heart diease vs Max Heart rate",xlabel='Age',ylabel='Max Heart Rate')
ax1.legend(*scatter.legend_elements(),title='Target')
ax1.axhline(y=over_50['thalach'].mean(),linestyle='--')

fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight='bold');

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
data['age'].plot();

# %%
plt.style.use('seaborn-whitegrid')

# %%
data['age'].plot();

# %%
plt.style.use('seaborn')

# %%
data['age'].plot();

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
data.plot(x='age',y='chol',kind='scatter')
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
plt.style.use('ggplot')

# %%
data.plot(x='age',y='chol',kind='scatter')
# Out:
# <AxesSubplot:xlabel='age', ylabel='chol'>

# %%
x = np.random.randn(10,4)
x
# Out:
# array([[-0.76070646, -2.75623737, -1.60849123, -0.39321738],
#        [ 0.07459282, -0.67958554, -0.05057137,  1.27871505],
#        [ 0.25607846,  1.88960912,  0.25994485,  2.4763548 ],
#        [ 0.47114205, -1.44833726,  1.38239927,  0.18357921],
#        [ 1.08105338, -1.47206025, -0.49673639,  1.00039359],
#        [-1.45681048, -0.21025207, -0.4845238 , -0.81841505],
#        [-1.89993905,  1.46111294,  0.96635275,  1.23258799],
#        [ 0.09362755, -1.81678898, -0.21630619, -2.05095325],
#        [ 0.19870308,  0.60691443,  0.31528466,  0.13897043],
#        [ 0.14039686, -1.50937264,  1.21792883,  0.58236622]])

# %%
df = pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -0.760706 -2.756237 -1.608491 -0.393217
# 1  0.074593 -0.679586 -0.050571  1.278715
# 2  0.256078  1.889609  0.259945  2.476355
# 3  0.471142 -1.448337  1.382399  0.183579
# 4  1.081053 -1.472060 -0.496736  1.000394
# 5 -1.456810 -0.210252 -0.484524 -0.818415
# 6 -1.899939  1.461113  0.966353  1.232588
# 7  0.093628 -1.816789 -0.216306 -2.050953
# 8  0.198703  0.606914  0.315285  0.138970
# 9  0.140397 -1.509373  1.217929  0.582366

# %%
ax = df.plot()

# %%
ax = df.plot(kind='bar')

# %%
plt.style.use('seaborn-dark-palette')

# %%
ax = df.plot(kind='bar')

# %%
plt.style.use('seaborn-whitegrid')

fig, ax = plt.subplots(figsize=(10,6))

scatter = ax.scatter(x=over_50['age'],y=over_50['chol'],c=over_50['target'],cmap='winter')

ax.set(title="Heart Diesase and cholestrol level",xlabel='Age',ylabel='Cholestrol')
ax.legend(*scatter.legend_elements(),title='target')

ax.axhline(over_50["chol"].mean(),linestyle='--');

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2,ncols=1,figsize=(10,10),sharex=True)

scatter = ax0.scatter(x=over_50['age'],y=over_50['chol'],c=over_50['target'],cmap='winter')
ax0.set(title="Heart diease vs cholestrol levels",ylabel='Cholestrol')
ax0.legend(*scatter.legend_elements(),title='Target')
ax0.axhline(y=over_50['chol'].mean(),linestyle='--');

scatter = ax1.scatter(x=over_50['age'],y=over_50['thalach'],c=over_50['target'],cmap='winter')
ax1.set(title="Heart diease vs Max Heart rate",xlabel='Age',ylabel='Max Heart Rate')
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])
ax1.legend(*scatter.legend_elements(),title='Target')
ax1.axhline(y=over_50['thalach'].mean(),linestyle='--')

fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight='bold');

# %%
fig.savefig('Heart-Disease-Analysis-plot.png')
